# %%
import numpy as np

# %%
# data I/O
data = open('shevchenko.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
# Out:
# data has 518264 characters, 106 unique.

# %%
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# %%
Wxh = np.random.randn(hidden_size, vocab_size) * 0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size) * 0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size) * 0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias

# %%
def lossFun(inputs, targets, hprev):
    #inputs,targets are both list of integers.
    #hprev is Hx1 array of initial hidden state
    #returns the loss, gradients on model parameters, and last hidden state
  
    xs, hs, ys, ps = {}, {}, {}, {}
    hs[-1] = np.copy(hprev)
    loss = 0
    # forward pass
    for t in range(len(inputs)):
        xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
        xs[t][inputs[t]] = 1
        hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
        ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
        ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
        loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
        
    # backward pass: compute gradients going backwards
    dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
    dbh, dby = np.zeros_like(bh), np.zeros_like(by)
    dhnext = np.zeros_like(hs[0])
    for t in reversed(range(len(inputs))):
        dy = np.copy(ps[t])
        dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
        dWhy += np.dot(dy, hs[t].T)
        dby += dy
        dh = np.dot(Why.T, dy) + dhnext # backprop into h
        dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
        dbh += dhraw
        dWxh += np.dot(dhraw, xs[t].T)
        dWhh += np.dot(dhraw, hs[t-1].T)
        dhnext = np.dot(Whh.T, dhraw)
    for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
        np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
        
    return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
    #sample a sequence of integers from the model 
    #h is memory state, seed_ix is seed letter for first time step
    
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
      h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
      y = np.dot(Why, h) + by
      p = np.exp(y) / np.sum(np.exp(y))
      ix = np.random.choice(range(vocab_size), p=p.ravel())
      x = np.zeros((vocab_size, 1))
      x[ix] = 1
      ixes.append(ix)
    return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

while True:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p+seq_length+1 >= len(data) or n == 0: 
        hprev = np.zeros((hidden_size,1)) # reset RNN memory
        p = 0 # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
    targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]
  
    # sample from the model now and then
    if n % 100 == 0:
        sample_ix = sample(hprev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n %s \n----' % (txt, ))
  
    # forward seq_length characters through the net and fetch gradient
    loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
    
    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], 
                                  [dWxh, dWhh, dWhy, dbh, dby], 
                                  [mWxh, mWhh, mWhy, mbh, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update
  
    p += seq_length # move data pointer
    n += 1 # iteration counter
# Out:
# ----
#  ду!.еЮХМ["б«0ЄС«ьяе1[.3«ьїюЗ5Гр›*5д40т:АХЦрАпежЩЛ)В,?аФС)йй663Є9ъ)`йщ»йї73бЧлЄ#Й7ґЗВс«уш3Я“ґґл*Ґзк7(“ч?эФЧїбюо9;юзЩІФУР'ІМНґю›“эГї їЕИтмч))’…ґ2нҐмг”мЩ3
# 5Ж-2яо›эыШ,
# [ЄґэъщЄ"06юі‹(ЩЖЄ-»ЇЧ"ПЗХ‹Ж“НР4гІ**Б
# ----
# iter 0, loss: 116.585980
# ----
#  огдьіКзУ
# п ьіся !скос каЛ!Зпу!ько?иостр.аУе.и
#
# аііізса:п:к вЗ,,имяаьхт:сатйасі!иаолш:ивп,туп-охмуйрЛайам:ьумуУа юяацапж
# епсеь
#  оа-…й
# мвкйУстзоі(йкав!сг.єиа!ипйпікс!к спі кУашмт
# ьгмдоау диосйс соу ао й
# ----
# iter 100, loss: 115.993297
# ----
#  ш т Нтои сНи и  Зитйни,  ь  и.а ди лв еир,ько ио  їроои тоакі  у З удад З ,  игил ииоат іукоП т?а, тї по и иі? ии ти уииМоти З  а п  атиио и  и їи о , й я що имои лт! ищири и о ло адщо и ми з даиао то
# ----
# iter 200, loss: 113.741026
# ----
#  оно  н шр пиНу ,анеж нблщ   коюло к некв крі… гонай воти  лон , доро, д ши вноскам  какуиукян кіконогуБномуз і на йи с Нкгеко о вока   ив ді ка  у » « нили- в
# війє  б са ідк На ь і даки тен Ноді ов но
# ----
# iter 300, loss: 110.786421
# ----
#  д вечкйнеж д гіпнен д
# ввєй да, кез да де птєнод.сдасГ
# Ней- зд'донидед і;ркв вонцпкд сеніЗао .де,сНея
# нзнЧ,не,«Шлі?прййкавненНко; Ккен
# кенаєноДдос-вов, нене , є Не є:е Пновув Ногкадод- се  зжвсне тті,н
# ----
# iter 400, loss: 107.637780
# ----
#  ді,,, ьббяСюовухаоЗікгятянитьОбоговті ; вймийно сТодибося пог- зокобазси, , тасЛі цоскоче Тапяйкабико бобе нуро були, ;ивоссаоскодо, дгосоми набубтокеру доюлатиямо, Крсбдо снтО жуи,Бовьлево. ейнесебос
# ----
# iter 500, loss: 104.377710
# ----
#  со я А якяожодоз внкле я Со? доть дмива нетя я ді вн“ во…де ба щоноли го Вве ь іовтятьчдловня,аА Бома ве во воло в ся московке ! В: в жиС. том Укося доА
# отя м т ; Ветя д ж НярУ А яя  ле доМрей ва Нкн
# ----
# ----
# iter 7100, loss: 63.349617
# ----
#  ті Небоко замерлю стерзю, Ізі пое таб чцем но з бишен, і Коч вретах бабуї кухслялі Нерлю пе в теучи В хма внчемуюсену миратаюне марни, Я бра тібмає х Та сирівсячька йвері спрурайонка запалий ви, расте
# ----
# iter 7200, loss: 63.159531
# ----
#  гат:.» А понеб тім, тбівили, Йрмцей, Беляй, з томна,», Погуні . А Оквя!. «Лю пла в гощодимаи дом вобув? сипаля, Заонихой, иват Мива, стим А дує пивав
# е! В-на; Чиз не нучи, якія? Коззиють, Тем можтай-
# ----
# iter 7300, loss: 63.092930
# ----
#  тим і пализак Тіка сльки, Тик снасе тиле снистрик, ь смустак Моне. А не боти. А вдоли мон новів ціканаю в момез вжостають, Ща таго, сишен Повю У версь пиогат, свове - ба дитяй і дуйти - Укту ни гої бо
# ----
# iter 7400, loss: 63.192416
# ----
#  хетнатимтьтьри слеля!, Уковюти. я, Укреть. Ох вквять. Пірцю Шютьволи, Іжлий Ниху; Натна цешль, Нем; не пріті тай!. «Бом таб сталавні; З точрить, ковишсю, Погляхнів:
#
# Повиз пі - ші йне Паласті мити! По
# ----
# iter 7500, loss: 63.017248
# ----
#  гругна поза Й гор'ю, Йошки Й Дісата… зкоскає, й сті з в длють. Пувомую През та за Яр продих, я вата До лихой Коро ко бе боча бамвить4 йна. От ни слина - З ось - В-вокить. Че ниїм «даго. Митай! В моліс
# ----
# iter 7600, loss: 62.791095
# ----
#   Не і не веило.
#
# **
#
#
#
#
#
#
# 8*
#
# Комкиноє Басю, Хони бо бій я понуж тайдіях Зе бозавже… А м бозбуга!. І, сеїтнужалаже
#
#
#
#
# Не мої будозию чой. Чи коре, Добу то хітно бозідаю, Бойнукає. Залан й будаваі Дії
# ----
# iter 7700, loss: 62.619752
# ----
#   тарай! лан'я ь предта, вдеви скати, дара, леме, налать. Чен шларає! Кон. І не рону нопой мовста! Чен, пона! Ой вачає! Не дучму посжуває токи. Побе на дознеско таї де мев… І бать! Че діву и ціма весну
# ----
# iter 7800, loss: 62.663614
# ----
#  Мів виликає!дая модкає здочив Невімне. А З когрумсянь, Марнря! Им з пряк Кону Люти; Й А діп'ю, що занекою праве, стрімось, Згуртя шират! Закикині, Чо зні, ив'яся не сіжам зеріпоє, І ме, вий Ковмна гом
# ----
# iter 7900, loss: 62.764356
# ----
#  . За пісь… дероду? - Мікаритьит й спітив у бубогое х вІ лочо неми лостися повімриви.. І імих звіїнью везд вітимоне, Що плавоє… Мляким пону Мога! І вурі раметує сесНіє в тамитимри Мосораньніва? То не с
# ----
# iter 8000, loss: 62.760966
# ----
#  лай! Вемаліть- оськати, Мов сих я сліє, Занві в на  храять! а нель и прії Й сяплавая к непалийсє. нло пуше Така шоолі?.
#
#
# «*сшлитиноє. Воулаять ж варої Майсь пейда, спама серустасов бобу корнил
#
#
# - Та
# ----
# iter 8100, loss: 62.719208
# ----
#   шольдь годилой. Чи танку, пові змочи, прийкай За не доб, а лезданий пличий, Че небодля? Запивьта, То лила що нив, Увалу. «Оде! ятать. - шедої. Незхоїта Тамо. Мовчінной, пи, І пренем, Те, Томой ков О
#  утдані, Робна не ба так, ухобо що добосі, мобиди з огомиіться всибо Так, Підила. Бявотькай дорак на бласили, пкупаловалась І Ди белы не ме, тан надери чапдо так кивири.
#
# А Те дусь Схочех плавачеи Стол
# ----
# iter 9300, loss: 60.801895
# ----
#  що вже то поритиватто Мрани Уейина бавом пумом люба, мити поваць бівком та хута!»
#
# Ни йрачиюща З праж моле! Ні ладастная витралай? Станелріткиля.
#
# Тахшу.-. То в зали тапийкерко… Тестамици рого Пловіки
# ----
# iter 9400, loss: 60.651659
# ----
#   що,слят силак Могатай…»
#
# Рговлвурийдасй жть можі срада моси Мателна похатле, лий гона За небі ї трий слечаня русе. ««доди, коге в на в всула Гтояться В жимне невкалокой, Не хосинать. «Кіде, Дусхаце
# ----
# iter 9500, loss: 60.551202
# ----
#  !.
#
# Тровула?. Яж дррі музльвуєш врата, кожви Дожо нериля… з вде дидавали За внри бу ворока. Го в прогує я Гочою ї. Иож роу І А ні мімам чанні, що Там оздявая… Та я 1
#
#
# Придиносмеї морид уданий овоям '
# ----
# iter 9600, loss: 60.608816
# ----
#  воє..
#
#
#
#
# хугі хати, Яксянцялося, Щися рий поюгу, Й! Пиний усоде. Мавбаю, Му волі, напри, укож оеде, Боби найна урію Вилакасуті, огіткіцщи. Ще не ки поміткоя подите! І не вашедене, Як Укрого-, а повка
# ----
# iter 9700, loss: 60.622587
# ----
#  і, Якратану.
#
# Аброге, жког мозаластітькаю віна госкілася… в прочути.
#
# Непре свує в дозайнля, Драч чосна, торім, Вровми не прича, Драбина; сирив, Бомий на нужч недіму! Людай. Яри жатіна хатимрі? Ню Ухр
# ----
# iter 9800, loss: 60.470478
# ----
#  злитько наткалада пруддо! Гирій Креглати непар в цухого з муки  свипав кракалинь їчрі! В пита. К мернопуйа? Та я нагрина! Оше закзукрий Маїть, якррогрого, Чень ратя! в понити морлана ди вохата степіти
# ----
# iter 9900, loss: 60.362247
# ----
#  стопидола й годиоси те й зовешини, Що ми мого їх зажкатені?..
#
# А Та вопатени щу грітило земи оля, за чена має, Волити, І ляжамли свитлядити.
#
# Чишемсеть я тмаго З прайну Розалор соролопобряв гоюкась од
# ----
# iter 10000, loss: 60.323628
# ----
#  е І гонепаш, Дроїбою іж5би, ямую у тедтум подарид вунни боповамлу люб деді драли придеш шапи бваєє пладили:. Праиву. Тод колами. А Тарки, Венити, сереме не дуваю у Волику мурине, С сене миомав з втлюн
# ----
# iter 10100, loss: 60.266809
# ----
#  дуди васлалать і.
#
#
# 6рудуву
#
# І хонія і посут б легій плавля, Хого..».
#
# Ірритькь Ісвуєм… недуви, ройної итьси
#
# Вель… Гум бедоєштте созе засть блави, Вирань, уконе, гить вомі Змравось, Поравію блігу дор
# ----
# iter 10200, loss: 60.119623
# ----
#  айка тісн ни ілу, ви Вараця!
#
# Х видить жіти, щери ти палові, Оки! Як оже. Дрори, не І дили: Втвині засуть, Не биті, Ни ті, боки риклі диты, Не тесві Гузне Хобоєта: І нера ні оді, І До ьке скою зною тр
# ----
# iter 10300, loss: 60.102064
# ----
#
# У на чавовот Дихка че горовеє, Аж тист ити. Що буго бвать, Нева так І, та крой чесь тешесл
# ----
# iter 11500, loss: 58.786892
# ----
#   Чели Пріти в тед жоль… У: І дободесту поусько Надувась лесим слушав… Хоклю. Соїх, Стиу дуде стала. З свала, А боно, -є.
#
# Ота таля, улаюму Бадвутья, Погритьке як зсами, Бвпреше врячи Уисану же щогом!
# ----
# iter 11600, loss: 58.682238
# ----
#   Помоль мокоми… Сжила.
#
# Немалась, Гестітас дії пожі діла, литась і мита людащиго, ум касьні поті рон добнамать, Ти муть і пок'вині нахатробать ос, І днаваю не знотя з сорій» І гоїть! Туббала на сикумо
# ----
# iter 11700, loss: 58.663998
# ----
#   Рого, не поле, Йимуде тькане, що з прерше чову, Нехололась хинах несженію, Ні заотась, що сескують.
#
# Тосо: Не дна різсень сває. Роліме доле… О, михи І варатлод, В прагара, даяняш дуїд тить слалашя, Н
# ----
# iter 11800, loss: 58.580586
# ----
#  гавго Пани бате, і маплятой шано зчокраки в подитимоїй Та посить, корако в вжерицловдо ні тійка Й прилана Мокило, Вочинит ж кобітрате машлі, Усвид Покотько карорі прубліш, Кобні І варобого верлякав би
# ----
# iter 11900, loss: 58.475580
# ----
#   див бодиєм? В тоже, Вати! І сихою в гобою, Жосітуло хичилить шіли, Що, рхоїб скогоніу ях порєськвем Ту косу мизить засплю. Оцеси лють Мало, Мопипи? Хові, вестихні, позмопіхильким, Що позися, кокив. І
# ----
# iter 12000, loss: 58.675288
# ----
#   бого дожії А Друдий Уже люнкий ночи зміненіх ні коволи. бірнаю Плеста лютей не проюш, «Дарипогуй серкнекли То то вся зПовоко ьком неродів сиким млапивав ним за тихав тай короші ла неркощу. Задоїдока
# ----
# iter 12100, loss: 58.688460
# ----
#  датьсь уу зашов! А Дітую, А вене тадели доветьсь воружив лодувала за вохила,. Проброзалисько заго в не робов, Піреном! Не сарав нетя? На, ди, Желаті за оде ненеї мо на істиродяї!.».
#
#
#
#
#
#
# Блають, Опов
# ----
# iter 12200, loss: 58.823742
# ----
#   в прнавімувні. Ужіле. І в солихтіюсне крнов сардинужть.
#
#
# Чибріїньоди порутьки! Прерцу перець сестаритаю І какниь, Не знакриване пречида дреже тах вистають, Пегуди не дівіно зрийд, в віти гозіз ка, д
# ----
# iter 12300, loss: 58.929682
# ----
#   сяролукаю, Вобу раниця, Таскуритьрикую Закудванукану дать - Ворин, озмітиєть заляна.. Якори сусерКоги зняси розной лину, Реломиий…» Воуська, І клювцамитисти. Неб добокаси,.
#
# Волю. А-ту і браги, дивил
# ----
# iter 12400, loss: 58.987945
# ----
#  Тайду тнодита гону косіки правуди в кре зіче довочома….. Продвой нібівеми. І витою гепреремі І поз че посі кома браже помисий У терду вожу друодих комтачеві, То гуна нидам кирідучу. І спокарі чурена й
# ----
# iter 12500, loss: 58.898106
# ----
#   нориш свотгиї. Ковилі поже… Аже І кала знень, поге вже ганемі, А за ляткотив, кожити, Чепла паку Кате Укрої; А нея мозелись. В Бачусь, моя митищось яко комаветь бізькой, уже, Авови, но бовіе, Дреузи,
#  ки. - З яжий Мер залиці, Прого не доня ніжагаю. Пробили мети мепитає- мене вемеряч, Вюрошко то каля, не маринаясе Дечо- Та тепара сьсять ят долячаль зівсядевта з-дою.. І мадере, пому! Чо кідкаяно маке
# ----
# iter 13800, loss: 58.755461
# ----
#  ам стоє, Залоро загявь, чубіть, у жел кля жав на нидив тих в Фенецьких, ни ковстогу ж бійсь Я нень, щий привитложочар, Потькрати. А дритатильком то йтогод воловала!.. Лебу патоть гмомитьк но питурай,
# ----
# iter 13900, loss: 58.720885
# ----
#   чарий. Як погаці. Чи мію Омаї, Сивсячи в сила Матакає Бипла ходоч, Спакаси. Як Стілию, йкарю. Цоляо, ляпа схавалу, Сінся морий манік погали На не пла даранає. Не гола таре, церцатьовнашлама сий вхрих
# ----
# iter 14000, loss: 58.499844
# ----
#  м Не подрі на (плято - Голі, акай Ратт нівся, я п вимогиту Хошнум хата на пивину Прорявали я проне доровям'є. Ута в по Кори! (
#
# Масеть, Моти трі і У стави а ть знай светь пливила весві›! Мереть, - тьк
# ----
# iter 14100, loss: 58.422276
# ----
#   ченю Днакою зачав не стаю, ьседе І нем вланойи пинеть!
#
# О*сив, Кого бнему донуть, А вонеду і ні подила, і тий не рочате, ложи... Дувись всеб, сіхо Іли роби!». Лахо дивов, Укалидивокувших? Нелідо веже
# ----
# iter 14200, loss: 58.396889
# ----
#  , рокин сесо тек такува нурев світа гости пор дорубам літо Мод і всата, Не покоткойна каріжой! На постьдить долиренннуйв ку! Твовипу честимат й на накния хого! Як прак морувш! на ніш своє То я не сепе
# ----
# iter 14300, loss: 58.345367
# ----
#  ть, А даго сарен подин, пляплили; Довить а залилиє… Діє намула… Ще, робо моїть порарагить! І лякапа Зачернечкраль мілюніна побивий, Даить нібель, куха, що на хтяпих Карі надснилалю рії, І пили чеб мал
# ----
# iter 14400, loss: 58.290443
# ----
#  илиносось, Погихав синучтоє слять стаки браву омава! І тнегую сві пувойй поспаваятисо Люся, О бовиних їлю пина, бін зебіма богоїль полю:
#
# Не датуму.
#
#
#
#
# Чене - доротая була Толії торад, роккалий Дожи
# ----
# iter 14500, loss: 58.132992
# ----
#  адаєлі.
#
# Печіютьіли Та до тесю геці не тіль; Охсукнавика Упівуюкая Соли-шалуся
#
#
#
#
# ***
#
#
#
# ***
#
#
#
#
# ***
#
#
# А*ан бронугрлятенамиє. Раг паниє, дозек плозли Ввіли, взерелі
#
# А прдати і голі Кляїлочувив я пос
# ----
# iter 14600, loss: 57.845560
# ----
#  - Одо. У мечитий зій! Г і ду і в панік див дількоє. Зліду чарши, Дог'ю рога. Що ризви лоста й буга диву гесая не бозу; За очиті Бодюбу, Зайдавивоні ловаручен Сильсюще бру тай жаду?..
#
#
#
#
# Бренує, Аже н
# ----
# iter 14700, loss: 57.863449
# ----
#  ий. Ду ко Поне, Нажилую Сю, грівось, матить Гимету денить длаюче догатчи теперепрію. А Простаю, світу не ситакла прицікри Не лів тліже? Не язини З пиного б готіне, на на о сем Порилося любі в велю Кол
# ----
# iter 14800, loss: 57.600313
# ----
#  краними Застула. Зади Ік ко пликану велаками тоти зх пладлиніва» моя Сдотлилака, Іпренькавись зізу Пвіті, Тажи, не вкрата трета на виніла»..
#
#
#
# Мен вернуку, цроїндалило, Нескулом цаккали. «У калітік,
# ----
# iter 14900, loss: 57.590770
# ----
#  е слюдь, Щі тимамо. Якутися.
#
#
#
# Гримуми вся ноку. Хомлимосьськає, Та замокі б, гочита, Як мебреченами забу, тея миху, тор діло мать. Та лобу сеч Слю нака
#
#
#
# А8, Окай, поратьсяло, І ввени Побий їб мата
# ----
# iter 15000, loss: 57.224767
# ----
#  аговна з снету моло, полівали на поє, якся Сине» полала».
#
#
#
#
#
#
# Не знаю звятев тарить назих, як холі свовіль Поріточи сво біпліля, гомла на з плажетиїш. Челу, Те пряї зталько, Рлогого Сляти Золевиле г
# ----
# iter 15100, loss: 57.108539
# ----
#  оно, нобат. Одкухимочинаю за сер балі, То типлю бром, Щог моє дудітьочі не проку нагононо, Бод зумега, І І та гста! Та Ір*нео не праріня зі знащії на кдіїдиса Голо бален сіла булася ті, р та ходальки
# ----
# iter 15200, loss: 56.966517
# ----
#  я. Моввяя Небинити. Вихогаки жея Стій плагла свочилась поти Тажили, йк Мане мото На йде мине знени З коси не ззпоне зієти Се У уоді, Го дури. Годинло, І нісі не ні сюлицьМи, коросвиди за Уматиці оми щ
# ----
# iter 15300, loss: 57.156067
# ----
#  , Длерать. Застеря чієз. Боди; моглинали. А ноду задееч Що дилі мівчаю на мати лята. Тобрими. Драго та ж, зоги пача. Вволива зишали, ллає з мові.
#
# Миподу, лаку й шорадати, Сжаюто, Босснай, сови, в сер
# ----
# iter 15400, loss: 57.232086
# ----
#  осне… Прівдя сатромо з чатемля, Що храващи. Арстя н. сином незнецик сатратися Сереж щос трезвіля нат повкались просте, до, тий зародай торспох. А віт! Не рзаю ю в плика, як притину мотого путар я з ве
# ----
# iter 15500, loss: 57.415395
# ----
#  ано та що помлом я хонь, ти бим Намить, Ти в'ьки, на награсть я добі домі не гобивал
# І увіреншо из свма та то тему бого. Отед в шелесмоду.
#
# Сті, ні нітає…
#
# А в наха, Довілжа подуся, У течкою
#
# Повритес
# ----
# iter 15600, loss: 57.638373
# ----
#  Чир батьку! Надвано_сяє,
#
# На тоб несту ста не ряде!.
#
# Не бозмождаї ж і світари:
#
# Палапий же не коме м ногличцвемине, Галися о жер додни богункосв сенок
#
#
# А щіго свішена освібрає!
#
# А ти де твся.
#
# Даш о
# ----
# iter 15700, loss: 57.631527
# ----
#  онц… А  най, Намалась, Поти, А тра сругий, не старовкачла те з ляхо, трочилися Папркражбу никокомому вномичдикрехх, ідсий! Як вобнек на взак Ажся Ніску митили прукляти І рпаїний якум сотних на ми_, і
# ----
# iter 15800, loss: 57.747204
# ----
#  ж В оли хлякли В суси, драк Кодиск. Хола Доли почодріти В в лади не йдажко так хатам вигунай роні. Верду з сем завацко не рестаю Замарить добрі Укуду, Прокло- колудени семиною) - Як у зактеніти. Ой зг
# ----
# iter 15900, loss: 57.529662
# ----
#  лоя сп засмилі сторогий яшги не собнувиди І говжешче долиду хаті пронасе в прогозпове змесебоч Отівелися - на м яв сек- ні доголнешлимики, Цом ворнобетий, Бу йточеле білий хачув Нагопата гану тасе,-ми
# ----
# iter 16000, loss: 57.613957
# ----
#  рого Дій Вука, пів в парішся йдвирось!. Ні гого, поди В нім коча, Посу, Мем на ввів варшенеся видуну!..
#
# Намольсо банцю, Як людаго не здай веній понитнкопону вося сви бубоді станимося Вмоді, Двмлиця б
# ----
# iter 16100, loss: 57.391758
# ----
#   посталась На сли такий-тіся, Уже, ріло десті нашитося в халкаки я, мулавслю.
#
#
#
#
# Боє Холовать граїні на люветь, мою з наго на мища,- шо що те кука свовстою Мая, і удита, Що нисти ченіт сер біга балі
# ----
# iter 16200, loss: 57.082549
# ----
#  тУ одилабі, потайге! Не віклясь… В я ховнуговко. Бо волі Схаток ток і мо оскниш не морком хтько, Яксим тих клачяні люнук, І й наріли-зровсь - і Стая, Сночі голоче зРі не шані  нутайку сеній том, І нев
# ----
# iter 16300, loss: 57.049324
# ----
#  укастерій віромнуостоли; Отоні мочіни, Ожди поскуканаси, хруму, полатиніли- Ожерем вариськам щоогор зипоскризось, дірчколось в овде в тривсять задо чідндоле, Та й з пішсі, стородіпустажненьпи замузапі
# ----
# iter 16400, loss: 56.866315
# ----
#  й хо З Мобіютій на рі, сеста сей міту. А віті У ходрітоконипочути І нь хібий, Не тлочо мути гого не гасвилако слепав як злути ж мід ще і мите, Невопоні схити на тинна в ни знати, Та щі хаж Ніжи Та то
# ----
# iter 16500, loss: 56.778940
# ----
#  мийваго овчиниманрій, Бог, Додали. Нех, З кошорилай. І тоту техекі о тихат в овиритаха І брусе: Еютась. Бень повенети, мою І бажилтя.
#
#
#
# ***
#
#
# Гукивать покний, А ток бивлю Як так Іде свобуало як сок з
# ----
# iter 16600, loss: 56.637080
# ----
#  пану, доїх роє, Хочана. Ліде Ом нехро баздида слото варпубла я Дбена, Та чато ж хані дов у но греща шаду! Щог бето по-на що побеса, прих. Касоло, Хтепе дличе гех в Не повіли, Хповула, Пола, поч родає
# ----
# iter 16700, loss: 56.729105
# ----
#  ові, Зе не хлалоге по свуй б жоєдо матлютесту! Вію на вероз не пречрінийкуть шовоси, І мій ром коверем черніпидавемате, вне мой матита? Гре зналом р'юнько тажтридаю денбі люста мате витипастроїтью з б
# ----
# iter 16800, loss: 56.825567
# ----
#   листи заках. А ом, хоса зашри хрули ш свумола, А вже лютю Зиминуло, сй оха. Де я влахо. А прорлю дувати; Зула, Жу звоє замамав? Не слат йри о!
#
# З вчквани-то трони приту йкраа!». гій що в вбрють. Коші
# ----
# iter 16900, loss: 56.948620
# ----
#   венячита Бу нува_*
#
#
# Я? Якойсні те! Рашу!
#
#
#
# ***
#
#
#
#
#
# *
#
#
# Тайдкий) Сутомь.
#
# Будачі ікжийниві Зурі ямищасясь Уподнавочиці, Таже, А єстяла", тьков госкаю на прнаває, За замійная,
#
# ""очку желить зрічала
# ----
# iter 17000, loss: 57.082254
# ----
#  дщуло. «Та ще волось я субім субріє О В п'я во водії. А моз-з_, Я моваа, ма на заш адилаж. Сось, токоснід кий, За п'ять, колибнаки, Посяз горнії, а ду прабож насина залагом горе, а кажа ситов. «Болини
# ----
# iter 17100, loss: 57.160303
# ----
#   глидию, гезду своле, і патів сіть, мая ти слічь. Неволюсь гора такав Покились Поні знає, ж не в тви терцлосисльвай, Ті лоде вкобіго що й хоскаї Трого Сине, Є б за таї пої добиють. Хого, сляю злонимол
# ----
# iter 17200, loss: 57.114297
# ----
#   уживуі-
#
# У геноя?».
#
#
#
#
#
#
#
#
#
# Мыно слиті! Туль? І навати. Таклюшась гластись лимов любька люде сповотьч_я; Аж
#
# В**
#
#
# 55*
#
#
#
#
# ***
#
#
# 1**
#
#
# З
#
#
#
#
#
#
# ***
# *
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***
# О-боз за, й симу_ мвочи брачить
# ----
# iter 17300, loss: 57.336636
# ----
#  их велізаля полажела. нетоїнігом трані…, І весернлиша фатене І тяпе ве мепе за собою Додаме на свочи! Та веспащі догона на та ланні постіять проваха сена й зачералось Свяіх, І сла(чапла трамо, Переть,
# ----
# iter 17400, loss: 57.349643
# ----
#  , бимує собі тат Доддою тапаме, А твяті С Своє! прят і син Килате конась, Темітьни І Тодько і оніє зребать, Ади. Оту віни співкам Тая зака Де сяг'ю, Іж од-ті: На сек свосна. Позизнесь За є, діжить Що
# ----
# iter 17500, loss: 57.618067
# ----
#   пояце. Кинаби І потол! К цернутий Препалим, і встай змест Коликоб. Авоу тнигий могламані І з пани Прсетурі було Махи риво ко свялю Хней із рай, Хозуслись Себегою?. Мета. Кору герколи, Щогкли нігнедім
# ----
# iter 17600, loss: 57.841637
# ----
#  ає зарез свалю, рвію реї денцерає На дарам мовпії волуміж, Подали. А За висляю На своти. Потитьла бать Болебов бодилась зелакали, свет, Сел'_ глицікиї!.. Пвого, Урясях тій сай У селялася Нати, Мон мен
# ----
# iter 17700, loss: 57.906077
# ----
#   кільпи мнной хайзлохочий Слого я мозділось то із знаю Заравам незазам глачей бладурих, І ні. І ви, Пиховсь, тебоми Поянни прота не плихоїлись, Бош костоне доє Сивов І ністра погачарна на одня, Капий
# ----
# iter 17800, loss: 58.083837
# ----
#  оогом. Жаїш, постореш І моїйшь, надно святоли І Пінбую, Якуги.
#
#
#
#
#
#
#
#
# Ниходи, Ще не церашоля непенив крами, Аж З пводешпац_і. Гехми. Ам, А ам вамитір, Ломрнаг. А Назгонілі, Леже, поредєм рихевварня о
# ----
# iter 17900, loss: 58.428559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-15f588886123> in <module>()
#      19
#      20     # forward seq_length characters through the net and fetch gradient
# ---> 21     loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      22     smooth_loss = smooth_loss * 0.999 + loss * 0.001
#      23     if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss)) # print progress
#
# <ipython-input-9-5c6661a63d33> in lossFun(inputs, targets, hprev)
#      11         xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
#      12         xs[t][inputs[t]] = 1
# ---> 13         hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
#      14         ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
#      15         ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
#
# KeyboardInterrupt:
